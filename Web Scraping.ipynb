# %% [markdown]
# What is Web scraping?
#
# Web Scraping,web Harvesting,or web data extraction is data scraping used for extracting data from websites.Web scraping software may directly access the World Wide Web using the Hypertext Transfer Protocol or a web browser.While Web Scraping can be done manually by a software user,the team typically refers to automated processes implemented using a bot or web crawler.It is a form of copying in which specific data is Gathered and copied from the web,typically into a central local database or spreadsheet,for later retrieval or analysis.

# %% [markdown]
# Library used for web scraping
#
# Pandas: pandas is a library used for data manipulation and analysis.it is used to store the data in the desired format.
#
#     BeautifulSoup: BeautifulSoup is the python web scraping library used for parsing HTML documents.IT creates parse trees that are helpful in extracting tags from the HTML string.

# %%
import requests
Link="https://en.wikipedia.org/wiki/List_of_Indian_people_by_net_worth"
Link_text=requests.get(Link).text
print(Link_text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>List of Indians by net worth - Wikipedia</title>
# ...

# %%
from bs4 import BeautifulSoup
soup=BeautifulSoup(Link_text,'lxml')
print(soup)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of Indians by net worth - Wikipedia</title>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of Indians by net worth - Wikipedia
#   </title>
#   <script>
# ...

# %%
print(soup.title)
# Out:
# <title>List of Indians by net worth - Wikipedia</title>

# %%
print(soup.title.string)
# Out:
# List of Indians by net worth - Wikipedia

# %%
soup.a
# Out:
# <a id="top"></a>

# %%
soup.find_all('a')
# Out:
# [<a id="top"></a>,
#  <a href="/wiki/Wikipedia:Protection_policy#semi" title="This article is semi-protected."><img alt="Page semi-protected" data-file-height="512" data-file-width="512" decoding="async" height="20" src="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/30px-Semi-protection-shackle.svg.png 1.5x, //upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png 2x" width="20"/></a>,
#  <a class="mw-redirect" href="/w/index.php?title=List_of_Indian_people_by_net_worth&amp;redirect=no" title="List of Indian people by net worth">List of Indian people by net worth</a>,
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>,
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>,
#  <a href="/wiki/Forbes" title="Forbes">Forbes</a>,
# ...

# %%
all_table=soup.find_all('table')
print(all_table)
# Out:
# [<table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Wealth
# <p>Change
# </p>
# </th>
# <th><a href="/wiki/Net_worth" title="Net worth">Net worth</a> (<a class="mw-redirect" href="/wiki/USD" title="USD">USD</a>)
# </th>
# <th>Company
# </th>
# <th>Sources of wealth
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Gautam_Adani" title="Gautam Adani">Gautam Adani</a>
# </td>
# <td><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/>
# </td>
# <td>146.8 billion
# </td>
# <td><a href="/wiki/Adani_Group" title="Adani Group">Adani Group</a>
# </td>
# ...

# %%
our_table=soup.find('table',class_="wikitable sortable")
print(our_table)
# Out:
# <table class="wikitable sortable">
# <tbody><tr>
# <th>Rank
# </th>
# <th>Name
# </th>
# <th>Wealth
# <p>Change
# </p>
# </th>
# <th><a href="/wiki/Net_worth" title="Net worth">Net worth</a> (<a class="mw-redirect" href="/wiki/USD" title="USD">USD</a>)
# </th>
# <th>Company
# </th>
# <th>Sources of wealth
# </th></tr>
# <tr>
# <td>1
# </td>
# <td><a href="/wiki/Gautam_Adani" title="Gautam Adani">Gautam Adani</a>
# </td>
# <td><img alt="Increase" data-file-height="300" data-file-width="300" decoding="async" height="11" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/11px-Increase2.svg.png" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/17px-Increase2.svg.png 1.5x, //upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Increase2.svg/22px-Increase2.svg.png 2x" title="Increase" width="11"/>
# </td>
# <td>146.8 billion
# </td>
# <td><a href="/wiki/Adani_Group" title="Adani Group">Adani Group</a>
# </td>
# ...

# %%
table_links=our_table.find_all('a')
print(table_links)
# Out:
# [<a href="/wiki/Net_worth" title="Net worth">Net worth</a>, <a class="mw-redirect" href="/wiki/USD" title="USD">USD</a>, <a href="/wiki/Gautam_Adani" title="Gautam Adani">Gautam Adani</a>, <a href="/wiki/Adani_Group" title="Adani Group">Adani Group</a>, <a href="/wiki/Mukesh_Ambani" title="Mukesh Ambani">Mukesh Ambani</a>, <a href="/wiki/Reliance_Industries" title="Reliance Industries">Reliance Industries</a>, <a href="/wiki/Shiv_Nadar" title="Shiv Nadar">Shiv Nadar</a>, <a href="/wiki/HCL_Technologies" title="HCL Technologies">HCL Technologies</a>, <a class="mw-redirect" href="/wiki/Cyrus_Poonawalla" title="Cyrus Poonawalla">Cyrus Poonawalla</a>, <a href="/wiki/Serum_Institute_of_India" title="Serum Institute of India">Serum Institute of India</a>, <a href="/wiki/Radhakishan_Damani" title="Radhakishan Damani">Radhakishan Damani</a>, <a href="/wiki/DMart" title="DMart">Avenue Supermarts</a>, <a href="/wiki/DMart" title="DMart">DMart</a>, <a href="/wiki/Lakshmi_Mittal" title="Lakshmi 
# ...

# %%
net_worth=[]
for links in table_links:
    net_worth.append(links.get('title'))
    print(net_worth)
# Out:
# ['Net worth']
# ['Net worth', 'USD']
# ['Net worth', 'USD', 'Gautam Adani']
# ['Net worth', 'USD', 'Gautam Adani', 'Adani Group']
# ['Net worth', 'USD', 'Gautam Adani', 'Adani Group', 'Mukesh Ambani']
# ['Net worth', 'USD', 'Gautam Adani', 'Adani Group', 'Mukesh Ambani', 'Reliance Industries']
# ['Net worth', 'USD', 'Gautam Adani', 'Adani Group', 'Mukesh Ambani', 'Reliance Industries', 'Shiv Nadar']
# ['Net worth', 'USD', 'Gautam Adani', 'Adani Group', 'Mukesh Ambani', 'Reliance Industries', 'Shiv Nadar', 'HCL Technologies']
# ['Net worth', 'USD', 'Gautam Adani', 'Adani Group', 'Mukesh Ambani', 'Reliance Industries', 'Shiv Nadar', 'HCL Technologies', 'Cyrus Poonawalla']
# ['Net worth', 'USD', 'Gautam Adani', 'Adani Group', 'Mukesh Ambani', 'Reliance Industries', 'Shiv Nadar', 'HCL Technologies', 'Cyrus Poonawalla', 'Serum Institute of India']
# ...

# %%
import pandas as pd
df=pd.DataFrame(net_worth)
print(df)
# Out:
#                            0
# 0                  Net worth
# 1                        USD
# 2               Gautam Adani
# 3                Adani Group
# 4              Mukesh Ambani
# 5        Reliance Industries
# 6                 Shiv Nadar
# 7           HCL Technologies
# 8           Cyrus Poonawalla
# 9   Serum Institute of India
# 10        Radhakishan Damani
# 11                     DMart
# 12                     DMart
# 13            Lakshmi Mittal
# 14             ArcelorMittal
# 15            Savitri Jindal
# 16                 JSW Group
# 17    Jindal Steel and Power
# 18      Kumar Mangalam Birla
# 19        Aditya Birla Group
# 20            Dilip Shanghvi
# 21                Sun Pharma
# 22           Pallonji Mistry
# 23  Shapoorji Pallonji Group
# 24                Uday Kotak
# 25       Kotak Mahindra Bank
# 26              Sunil Mittal
# 27        Bharti Enterprises
# 28          Hinduja brothers
# 29             Hinduja Group
# 30               Azim Premji
# ...

# %%
writer=pd.ExcelWriter('networth.xlsx',engine='xlsxwriter')
df.to_excel(writer,sheet_name='List')
writer.save()
